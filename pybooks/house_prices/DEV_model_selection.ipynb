# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %reload_ext rpy2.ipython

# %%
import numpy as np
import pandas as pd

from kaggle.house_prices import api
from kaggle.house_prices import helpers
from kaggle.house_prices import model_selection
from kaggle.house_prices import utils
from kaggle.house_prices.notebook import Plot, ggplot2

################################
# load data, missing, outliers #
################################
combined_dataset_step1 = api.stage1_transformation(helpers.load_data())
combined_dataset_step1.shape

################################
# transform numeric predictors #
################################
combined_dataset_step2, trans_config = api.stage2_transformation(
    combined_dataset_step1,
    threshold=20
)

trans_config

utils.frames_diff(
    combined_dataset_step1.drop(columns=['price_log']),
    combined_dataset_step2.drop(columns=['price_log'])
).head()

####################################                
# transform categorical predictors #
####################################
combined_dataset_step3 = api.stage3_transformation(combined_dataset_step2)

utils.frames_diff(
    combined_dataset_step2.drop(columns=['price_log']),
    combined_dataset_step3.drop(columns=['price_log'])
).head()
# Out:
# (2917, 81)
#             var  progress_score  tran  \
# 0     GrLivArea       91.157942   log
# 3       LotArea       78.864026  inv4
# 4  TotRmsAbvGrd       30.685015   log
#
#                                              tran_fn      r2_x   r2_tran
# 0  <function stage2_transformation.<locals>.<lamb...  0.525931  0.543804
# 3  <function stage2_transformation.<locals>.<lamb...  0.067883  0.159187
# 4  <function stage2_transformation.<locals>.<lamb...  0.289123  0.293868
#    GrLivArea.1  GrLivArea.2  LotArea.1  LotArea.2  TotRmsAbvGrd.1  \
# 0         1710     7.444833       8450   9.587694               8
# 1         1262     7.141245       9600   9.898464               6
# 2         1786     7.488294      11250  10.298836               6
# 3         1717     7.448916       9550   9.885550               7
# 4         2198     7.695758      14260  10.927728               9
#
#    TotRmsAbvGrd.2
# 0        2.197225
# 1        1.945910
# 2        1.945910
# 3        2.079442
# 4        2.302585
#   Alley.1   Alley.2 BldgType.1  BldgType.2 BsmtCond.1  BsmtCond.2  \
# 0  _none_  2.531822       1Fam    2.564039         TA    2.540871
# 1  _none_  2.531822       1Fam    2.564039         TA    2.540871
# 2  _none_  2.531822       1Fam    2.564039         TA    2.540871
# 3  _none_  2.531822       1Fam    2.564039         Gd    3.046154
# 4  _none_  2.531822       1Fam    2.564039         TA    2.540871
#
#   BsmtExposure.1  BsmtExposure.2 BsmtFinType1.1  BsmtFinType1.2     ...       \
# 0             No        2.320042            GLQ        3.262019     ...
# 1             Gd        3.295455            ALQ        2.231818     ...
# 2             Mn        2.675439            GLQ        3.262019     ...
# 3             No        2.320042            ALQ        2.231818     ...
# 4             Av        2.900452            GLQ        3.262019     ...
#
#   RoofStyle.1  RoofStyle.2 SaleCondition.1  SaleCondition.2 SaleType.1  \
# 0       Gable     2.418054          Normal         2.451586         WD
# 1       Gable     2.418054          Normal         2.451586         WD
# 2       Gable     2.418054          Normal         2.451586         WD
# 3       Gable     2.418054         Abnorml         1.920792         WD
# 4       Gable     2.418054          Normal         2.451586         WD
#
#    SaleType.2 Street.1  Street.2 Utilities.1  Utilities.2
# 0    2.421468     Pave  2.499311      AllPub     2.496911
# 1    2.421468     Pave  2.499311      AllPub     2.496911
# 2    2.421468     Pave  2.499311      AllPub     2.496911
# 3    2.421468     Pave  2.499311      AllPub     2.496911
# 4    2.421468     Pave  2.499311      AllPub     2.496911
#
# [5 rows x 90 columns]

# %%
train_data = (
    combined_dataset_step3
    .query("dataSource == 'train'")
    .drop(columns=['dataSource'])
)
train_data.head()
# Out:
#       Alley  BedroomAbvGr  BldgType  BsmtCond  BsmtExposure  BsmtFinSF1  \
# 0  2.531822             3  2.564039  2.540871      2.320042       706.0
# 1  2.531822             3  2.564039  2.540871      3.295455       978.0
# 2  2.531822             3  2.564039  2.540871      2.675439       486.0
# 3  2.531822             3  2.564039  3.046154      2.320042       216.0
# 4  2.531822             4  2.564039  2.540871      2.900452       655.0
#
#    BsmtFinSF2  BsmtFinType1  BsmtFinType2  BsmtFullBath    ...      \
# 0         0.0      3.262019      2.553429           1.0    ...
# 1         0.0      2.231818      2.553429           0.0    ...
# 2         0.0      3.262019      2.553429           1.0    ...
# 3         0.0      2.231818      2.553429           1.0    ...
# 4         0.0      3.262019      2.553429           1.0    ...
#
#    TotalBsmtSF  Utilities  WoodDeckSF  X1stFlrSF  X2ndFlrSF  X3SsnPorch  \
# 0        856.0   2.496911           0        856        854           0
# 1       1262.0   2.496911         298       1262          0           0
# 2        920.0   2.496911           0        920        866           0
# 3        756.0   2.496911           0        961        756           0
# 4       1145.0   2.496911         192       1145       1053           0
#
#    YearBuilt  YearRemodAdd  YrSold  price_log
# 0       2003          2003    2008  12.247694
# 1       1976          1976    2007  12.109011
# 2       2001          2002    2008  12.317167
# 3       1915          1970    2006  11.849398
# 4       2000          2000    2008  12.429216
#
# [5 rows x 80 columns]

# %%
step1 = model_selection.find_initial_best_r2_predictor(
    data=train_data,
    target_var="price_log", 
    r2_discard_level=0.02
)
step1.head(6)
# Out:
#                     formula     predictor        r2
# 0   price_log ~ OverallQual   OverallQual  0.674705
# 1  price_log ~ Neighborhood  Neighborhood  0.547709
# 2     price_log ~ GrLivArea     GrLivArea  0.543804
# 3    price_log ~ GarageCars    GarageCars  0.463805
# 4     price_log ~ ExterQual     ExterQual  0.445239
# 5      price_log ~ BsmtQual      BsmtQual  0.435309

# %%
step2 = model_selection.find_next_best_r2_predictor(
    data=train_data, 
    base_formula=step1.loc[0, "formula"], 
    predictors=step1['predictor'],
    r2_gain_discard_level=0.5,
    a_max=0,
    a_avg=0
)

step2.head()
# Out:
#     base_r2                                 formula     predictor        r2  \
# 0  0.674705     price_log ~ OverallQual + GrLivArea     GrLivArea  0.764191
# 1  0.674705       price_log ~ OverallQual + LotArea       LotArea  0.746262
# 2  0.674705     price_log ~ OverallQual + X1stFlrSF     X1stFlrSF  0.745623
# 3  0.674705  price_log ~ OverallQual + Neighborhood  Neighborhood  0.736391
# 4  0.674705   price_log ~ OverallQual + TotalBsmtSF   TotalBsmtSF  0.733994
#
#      r2_gain  cor_abs_max  cor_abs_avg  r2_gain_adj
# 0  13.262860     0.608875     0.608875    13.262860
# 1  10.605577     0.164507     0.164507    10.605577
# 2  10.510875     0.469092     0.469092    10.510875
# 3   9.142558     0.679009     0.679009     9.142558
# 4   8.787371     0.538595     0.538595     8.787371

# %%
report = model_selection.greedy_r2_gain_adj(
    data=train_data, 
    target_var='price_log', 
    r2_gain_discard_level=0.5,
    r2_discard_level=0.02, 
    a_max=0, a_avg=0
)

report.groupby('step').head(1)
# Out:
#       predictor                                            formula        r2  \
# 0   OverallQual                            price_log ~ OverallQual  0.674705
# 0     GrLivArea                price_log ~ OverallQual + GrLivArea  0.764191
# 0  Neighborhood  price_log ~ OverallQual + GrLivArea + Neighbor...  0.813279
# 0    BsmtFinSF1  price_log ~ OverallQual + GrLivArea + Neighbor...  0.849388
# 0    GarageArea  price_log ~ OverallQual + GrLivArea + Neighbor...  0.861190
# 0    CentralAir  price_log ~ OverallQual + GrLivArea + Neighbor...  0.870262
# 0       LotArea  price_log ~ OverallQual + GrLivArea + Neighbor...  0.877606
# 0  YearRemodAdd  price_log ~ OverallQual + GrLivArea + Neighbor...  0.885986
# 0   TotalBsmtSF  price_log ~ OverallQual + GrLivArea + Neighbor...  0.891448
#
#    step   base_r2    r2_gain  cor_abs_max  cor_abs_avg  r2_gain_adj
# 0     1       NaN        NaN          NaN          NaN          NaN
# 0     2  0.674705  13.262860     0.608875     0.608875    13.262860
# 0     3  0.764191   6.423583     0.679009     0.573244     6.423583
# 0     4  0.813279   4.439874     0.242618     0.198366     4.439874
# 0     5  0.849388   1.389528     0.557230     0.454719     1.389528
# 0     6  0.861190   1.053398     0.272522     0.213866     1.053398
# 0     7  0.870262   0.843951     0.369755     0.232091     0.843951
# 0     8  0.877606   0.954833     0.549827     0.316392     0.954833
# 0     9  0.885986   0.616455     0.538595     0.400899     0.616455

# %%
report = model_selection.greedy_r2_gain_adj(
    data=train_data, 
    target_var='price_log', 
    r2_gain_discard_level=0.5,
    r2_discard_level=0.02, 
    a_max=1, a_avg=1
)

report.groupby('step').head(1)
# Out:
#        predictor                                            formula        r2  \
# 0    OverallQual                            price_log ~ OverallQual  0.674705
# 0        LotArea                  price_log ~ OverallQual + LotArea  0.746262
# 0      GrLivArea      price_log ~ OverallQual + LotArea + GrLivArea  0.794871
# 0     BsmtFinSF1  price_log ~ OverallQual + LotArea + GrLivArea ...  0.829395
# 0      YearBuilt  price_log ~ OverallQual + LotArea + GrLivArea ...  0.860887
# 0  SaleCondition  price_log ~ OverallQual + LotArea + GrLivArea ...  0.868805
# 0     CentralAir  price_log ~ OverallQual + LotArea + GrLivArea ...  0.874948
# 0    KitchenQual  price_log ~ OverallQual + LotArea + GrLivArea ...  0.882238
# 0   Neighborhood  price_log ~ OverallQual + LotArea + GrLivArea ...  0.888168
#
#    step   base_r2    r2_gain  cor_abs_max  cor_abs_avg  r2_gain_adj
# 0     1       NaN        NaN          NaN          NaN          NaN
# 0     2  0.674705  10.605577     0.164507     0.164507     7.980031
# 0     3  0.746262   6.513697     0.608875     0.489315     3.104436
# 0     4  0.794871   4.343360     0.222467     0.189010     3.077175
# 0     5  0.829395   3.796929     0.571368     0.268476     2.063724
# 0     6  0.860887   0.919745     0.347960     0.179732     0.602048
# 0     7  0.868805   0.707117     0.381792     0.187496     0.450597
# 0     8  0.874948   0.833154     0.662720     0.351394     0.413658
# 0     9  0.882238   0.672197     0.705746     0.444006     0.312686

# %%
report = model_selection.greedy_r2_gain_adj(
    data=train_data, 
    target_var='price_log', 
    r2_gain_discard_level=0.5,
    r2_discard_level=0.02, 
    a_max=1, a_avg=0
)

report.groupby('step').head(1)
# Out:
#        predictor                                            formula        r2  \
# 0    OverallQual                            price_log ~ OverallQual  0.674705
# 0        LotArea                  price_log ~ OverallQual + LotArea  0.746262
# 0      GrLivArea      price_log ~ OverallQual + LotArea + GrLivArea  0.794871
# 0     BsmtFinSF1  price_log ~ OverallQual + LotArea + GrLivArea ...  0.829395
# 0      YearBuilt  price_log ~ OverallQual + LotArea + GrLivArea ...  0.860887
# 0  SaleCondition  price_log ~ OverallQual + LotArea + GrLivArea ...  0.868805
# 0    KitchenQual  price_log ~ OverallQual + LotArea + GrLivArea ...  0.876226
# 0     CentralAir  price_log ~ OverallQual + LotArea + GrLivArea ...  0.882238
# 0   Neighborhood  price_log ~ OverallQual + LotArea + GrLivArea ...  0.888168
#
#    step   base_r2    r2_gain  cor_abs_max  cor_abs_avg  r2_gain_adj
# 0     1       NaN        NaN          NaN          NaN          NaN
# 0     2  0.674705  10.605577     0.164507     0.164507     9.107351
# 0     3  0.746262   6.513697     0.608875     0.489315     4.048604
# 0     4  0.794871   4.343360     0.222467     0.189010     3.552947
# 0     5  0.829395   3.796929     0.571368     0.268476     2.416321
# 0     6  0.860887   0.919745     0.347960     0.179732     0.682323
# 0     7  0.868805   0.854261     0.662720     0.370076     0.513773
# 0     8  0.876226   0.686041     0.381792     0.194897     0.496486
# 0     9  0.882238   0.672197     0.705746     0.444006     0.394078

# %%
report = model_selection.greedy_r2_gain_adj(
    data=train_data, 
    target_var='price_log', 
    r2_gain_discard_level=0.5,
    r2_discard_level=0.02, 
    a_max=0, a_avg=1
)

report.groupby('step').head(1)
# Out:
#        predictor                                            formula        r2  \
# 0    OverallQual                            price_log ~ OverallQual  0.674705
# 0        LotArea                  price_log ~ OverallQual + LotArea  0.746262
# 0      GrLivArea      price_log ~ OverallQual + LotArea + GrLivArea  0.794871
# 0      YearBuilt  price_log ~ OverallQual + LotArea + GrLivArea ...  0.837125
# 0     BsmtFinSF1  price_log ~ OverallQual + LotArea + GrLivArea ...  0.860887
# 0   YearRemodAdd  price_log ~ OverallQual + LotArea + GrLivArea ...  0.869877
# 0  SaleCondition  price_log ~ OverallQual + LotArea + GrLivArea ...  0.875808
# 0     CentralAir  price_log ~ OverallQual + LotArea + GrLivArea ...  0.880836
# 0   Neighborhood  price_log ~ OverallQual + LotArea + GrLivArea ...  0.887303
# 0    TotalBsmtSF  price_log ~ OverallQual + LotArea + GrLivArea ...  0.892516
#
#    step   base_r2    r2_gain  cor_abs_max  cor_abs_avg  r2_gain_adj
# 0     1       NaN        NaN          NaN          NaN          NaN
# 0     2  0.674705  10.605577     0.164507     0.164507     9.107351
# 0     3  0.746262   6.513697     0.608875     0.489315     4.373620
# 0     4  0.794871   5.315882     0.571368     0.274695     4.170316
# 0     5  0.837125   2.838434     0.249818     0.204212     2.357089
# 0     6  0.860887   1.044289     0.592105     0.319530     0.791410
# 0     7  0.869877   0.681793     0.347960     0.206578     0.565063
# 0     8  0.875808   0.574125     0.381792     0.203389     0.477090
# 0     9  0.880836   0.734194     0.705746     0.438352     0.510441
# 0    10  0.887303   0.587522     0.538595     0.374101     0.427568

# %%
report = model_selection.greedy_r2_gain_adj(
    data=train_data, 
    target_var='price_log', 
    r2_gain_discard_level=0.5,
    r2_discard_level=0.02, 
    a_max=0.3, a_avg=0.3
)

report.groupby('step').head(1)
# Out:
#        predictor                                            formula        r2  \
# 0    OverallQual                            price_log ~ OverallQual  0.674705
# 0      GrLivArea                price_log ~ OverallQual + GrLivArea  0.764191
# 0     BsmtFinSF1   price_log ~ OverallQual + GrLivArea + BsmtFinSF1  0.811298
# 0   Neighborhood  price_log ~ OverallQual + GrLivArea + BsmtFinS...  0.849388
# 0     CentralAir  price_log ~ OverallQual + GrLivArea + BsmtFinS...  0.859963
# 0        LotArea  price_log ~ OverallQual + GrLivArea + BsmtFinS...  0.869760
# 0  SaleCondition  price_log ~ OverallQual + GrLivArea + BsmtFinS...  0.879226
# 0   YearRemodAdd  price_log ~ OverallQual + GrLivArea + BsmtFinS...  0.885840
# 0    TotalBsmtSF  price_log ~ OverallQual + GrLivArea + BsmtFinS...  0.891508
#
#    step   base_r2    r2_gain  cor_abs_max  cor_abs_avg  r2_gain_adj
# 0     1       NaN        NaN          NaN          NaN          NaN
# 0     2  0.674705  13.262860     0.608875     0.608875     9.714068
# 0     3  0.764191   6.164409     0.222467     0.176240     5.505843
# 0     4  0.811298   4.694839     0.679009     0.463035     3.496791
# 0     5  0.849388   1.245057     0.272522     0.209468     1.087769
# 0     6  0.859963   1.139279     0.369755     0.218506     0.968381
# 0     7  0.869760   1.088279     0.328430     0.163967     0.948210
# 0     8  0.879226   0.752285     0.549827     0.312221     0.597709
# 0     9  0.885840   0.639890     0.538595     0.370830     0.502731
